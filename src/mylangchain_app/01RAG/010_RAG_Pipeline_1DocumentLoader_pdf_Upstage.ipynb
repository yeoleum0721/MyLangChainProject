# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add pypdf=">=4.2.0,<5.0.0"
# poetry add langchain-upstage

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# Fy

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader(file_path)
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)

chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_db")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
#   66개 청크 생성 완료
#   평균 청크 길이: 688자
# ==> 3. 벡터화 → 임베딩으로 변환
# ==> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (66개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001D31F63F800> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001D31F63C200> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다 (문서 3.3, 3.6, 3610.6 참조):
#
# ### 1. 일반 클래스로부터 객체 생성
# 1. **프로젝트 열기**:
#    - BlueJ 실행 후 `Project - Open...` 메뉴로 프로젝트 파일을 엽니다 (예: `examples/people` 프로젝트).
#
# 2. **클래스 아이콘 확인**:
#    - 메인 윈도우 중앙에 표시된 클래스 아이콘(Database, Person 등) 중 객체를 생성할 클래스를 찾습니다.
#
# 3. **생성자 선택**:
#    - 클래스 아이콘에서 **마우스 오른쪽 버튼 클릭** (Mac: `Ctrl+Click`) → 팝업 메뉴에서 **생성자(Constructor)**를 선택합니다.
#    - 추상 클래스(`<<abstract>>` 표기)는 객체 생성이 불가능합니다.
#
# 4. **객체 이름 입력**:
#    - 대화상자에서 객체 이름을 입력하거나 기본 이름(예: `staff_1`)을 그대로 사용합니다.
#    - `OK` 버튼을 클릭하면 **오브젝트 벤치(Object Bench)**에 객체가 생성됩니다.
#
# ---
#
# ### 2. 라이브러리 클래스로부터 객체 생성 (JDK 내장 클래스)
# 1. **메뉴 접근**:
#    - `Tools - Use Libraries Class` 메뉴를 선택합니다.
#
# 2. **클래스명 입력**:
#    - 대화상자에 **패키지명 포함한 정확한 클래스명**을 입력합니다 (예: `java.lang.String`, `java.util.ArrayList`).
#    - 최근 사용 클래스 목록은 텍스트 필드에서 확인할 수 있습니다.
#
# 3. **생성자/정적 메소드 선택**:
#    - 클래스명 입력 후 `Enter`를 누르면 생성자 및 정적 메소드 목록이 표시됩니다.
#    - 원하는 항목을 선택해 객체를 생성하거나 메소드를 호출할 수 있습니다.
#
# ---
#
# ### 3. 추가 기능
# - **정적 메소드 호출**:
#   클래스 팝업 메뉴에서 `main` 메소드를 직접 호출할 수 있으며, 매개변수는 `{"arg1","arg2"}` 형식으로 입력합니다 (3.3절 참조).
#
# - **객체 테스트**:
#   오브젝트 벤치에 생성된 객체의 **public 메소드**는 마우스 오른쪽 버튼 클릭으로 실행 가능합니다 (3.4절 참조).
#
# > 문서에서 명시되지 않은 기능(예: 단축키, 드래그 앤 드롭)은 **"문서에서 찾을 수 없습니다"**로 답변합니다.
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 컴파일 오류를 확인하는 방법은 다음과 같습니다. 문서 내용을 바탕으로 단계별로 설명드리겠습니다.
#
# 1. **에디터 재오픈 및 컴파일 시도**
#    - 오류가 발생한 소스 코드 파일의 에디터를 다시 엽니다.
#    - 에디터 상단의 툴바에서 **"Compile" 버튼**을 클릭하거나, 프로젝트 윈도우 툴바의 **"Compile" 버튼**을 눌러 전체 프로젝트를 컴파일합니다.
#      *(참고: 수정된 클래스는 아이콘에 체크 표시가 나타납니다.)*
#
# 2. **에러 메시지 확인**
#    - 컴파일 오류가 발생하면:
#      - **에디터 창이 자동으로 열리며**, 오류 발생 위치가 반전 표시되고 **정보창(information area)**에 에러 메시지가 출력됩니다.
#      - 정보창 오른쪽의 **물음표(?) 아이콘**을 클릭하면 해당 오류에 대한 추가 도움말을 확인할 수 있습니다(그림 8 참조).
#
# 3. **객체 벤치 상태 확인**
#    - 클래스 구현이 변경되면 **오브젝트 벤치의 모든 객체가 사라집니다**.
#    - 오류 수정 후 재컴파일 성공 시 객체를 다시 생성할 수 있습니다.
#
# 4. **주의사항**
#    - 일부 에러 메시지는 도움말이 아직 작성되지 않았을 수 있습니다(문서 14페이지 참조).
#    - 소스 코드는 자동으로 저장되지만, 시스템 불안정 시 **Class 메뉴**에서 수동으로 저장할 수 있습니다.
#
# > 예시: 세미콜론(`;`) 누락과 같은 구문 오류 발생 시, 해당 라인이 강조되고 정보창에 구체적인 오류 내용이 표시됩니다.
# > *"문서에서 찾을 수 없습니다"*에 해당하는 내용은 포함하지 않았습니다. 모든 설명은 제공된 문서 범위 내에서 작성되었습니다.
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### BlueJ에서 디버깅을 위한 중단점 설정 방법 (문서 내용 기반)
#
# 1. **중단점 영역 확인**
#    - BlueJ 편집기에서 소스코드 창의 **왼쪽 여백 부분**(줄 번호 옆 빈 공간)이 중단점 설정 영역입니다.
#    - 이 영역을 마우스로 클릭하면 작은 **정지(stop) 표시**가 나타나며, 중단점이 설정됩니다.
#
# 2. **중단점 설정 단계**
#    - **1단계**: `examples` 디렉토리의 `debugdemo` 프로젝트를 엽니다.
#    - **2단계**: `Demo` 클래스를 열고, `loop` 메소드의 **`for` 반복문 내 임의의 라인**을 선택합니다.
#    - **3단계**: 선택한 라인의 왼쪽 여백을 **마우스 왼쪽 버튼으로 클릭**합니다.
#      → 정지(stop) 아이콘이 표시되면 중단점이 성공적으로 설정된 것입니다.
#
# 3. **중단점 활성화 및 테스트**
#    - `Demo` 클래스에서 객체를 생성한 후, `loop(10)` 메소드를 실행합니다.
#    - 프로그램 실행이 중단점에 도달하면:
#      - 편집기에서 **다음 실행할 라인이 반전 표시**됩니다.
#      - **디버거 윈도우**가 자동으로 열려 변수 상태와 실행 흐름을 확인할 수 있습니다.
#
# 4. **중단점 제거 방법**
#    - 설정된 중단점을 다시 **마우스 왼쪽 버튼으로 클릭**하면 정지 표시가 사라지며 중단점이 해제됩니다.
#
# 5. **추가 팁**
#    - 중단점은 한 메소드에 여러 개 설정할 수 있으며, 프로그램 실행 시 **가장 먼저 만나는 중단점**에서 정지합니다.
#    - 문서를 참고한 예시에서는 `carTest()` 메소드의 `places = myCar.seats();` 라인에도 중단점을 설정할 수 있습니다.
#
# > ✅ **문서 근거**:
# > - "중단점을 설정하기 위해서는, 에디터에서 소스코드의 왼쪽부분에 위치한 중단점 영역을 마우스의 왼쪽버튼으로 클릭하면 됩니다." (27페이지)
# > - "마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다." (26페이지)
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# **코드패드란?**
# 코드패드는 BlueJ에서 **자바 코드(표현식 및 명령문)의 일부를 빠르게 평가**할 수 있는 도구입니다. 프로그램 코드의 의미를 조사하거나 구문을 테스트할 때 유용합니다.
#
# ---
#
# ### **코드패드 사용 방법**
# #### 1. 코드패드 표시하기
# - **단계**:
#   1. BlueJ 초기 화면에서 `보기` 메뉴를 클릭합니다.
#   2. `코드패드 보기(Show Code Pad)`를 선택합니다.
# - **결과**: 메인 화면 오른쪽 하단(오브젝트 벤치 옆)에 코드패드가 표시됩니다.
# - **크기 조절**: 코드패드와 오브젝트 벤치 사이의 가로/세로선을 드래그하여 크기를 조정할 수 있습니다.
#
# #### 2. 표현식 또는 명령문 입력 및 실행
# - **입력**:
#   - 코드패드 영역에 자바 표현식(예: `4 + 45`) 또는 명령문(예: `student1.getName()`)을 입력합니다.
# - **실행**:
#   - `Enter` 키를 눌러 입력한 내용을 실행합니다.
#   - **멀티라인 명령문**의 경우, 각 줄 끝에서 `Shift-Enter`를 눌러 줄 바꿈을 유지합니다.
# - **결과**:
#   - 결과는 코드패드에 표시되며, 타입이 괄호 안에 함께 출력됩니다(예: `(int) 49`).
#   - 객체 생성 시 `<object reference>`와 클래스명이 표시되며, 작은 객체 아이콘이 나타납니다.
#
# #### 3. 객체 관리
# - **오브젝트 벤치로 이동**:
#   - 코드패드에서 생성된 객체 아이콘을 **드래그**하여 오브젝트 벤치로 옮깁니다.
# - **객체 검사**:
#   - 코드패드의 객체 아이콘을 **더블클릭**하면 객체 상태 검사 화면이 열립니다.
#
# #### 4. 입력 이력 활용
# - **상하 화살표 키**를 사용해 이전 입력 내용을 재사용하거나 수정할 수 있습니다.
#
# ---
#
# ### **주의사항**
# - **지역변수 범위**:
#   - 각 라인은 독립적으로 처리되므로, 한 라인에서 선언된 변수는 다른 라인에서 참조할 수 없습니다.
# - **인스턴스 필드**:
#   - 오브젝트 벤치의 객체 이름은 인스턴스 필드로 간주되며, 코드패드에서 직접 새로운 인스턴스 필드를 정의할 수 없습니다.
#
# ---
#
# ### **예시**
# - **표현식 평가**:
#   ```java
#   "hello".length()  // 결과: (int) 5
#   new Student()     // 객체 아이콘 생성
#   ```
# - **명령문 실행**:
#   ```java
#   student1.setName("Alice");  // student1은 오브젝트 벤치의 객체
#   ```
#
# > 문서에서 찾을 수 없는 정보: 코드패드의 단축키 또는 특정 IDE 버전 호환성 관련 내용은 언급되지 않았습니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### BlueJ에서 애플릿을 만들고 실행하는 방법 (문서 내용 기반)
#
# #### 1. **애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메뉴에서 **New Class** 버튼을 클릭합니다.
#    - 대화상자에서 클래스 이름을 입력하고, **Type** 드롭다운 메뉴에서 **Applet**을 선택합니다.
#    - **OK**를 클릭하여 애플릿 클래스를 생성합니다.
#      - 생성된 클래스는 `<<applet>>` 태그로 표시되며, 기본 골격 코드(예: `paint` 메소드)가 포함됩니다.
#
# 2. **코드 편집**
#    - 생성된 클래스를 더블클릭하여 에디터를 열고, `paint` 메소드 등에 원하는 코드를 추가합니다.
#    - 샘플 코드는 주로 `paint` 메소드에 포함되어 있습니다.
#
# #### 2. **애플릿 컴파일**
#    - 클래스 아이콘에서 마우스 오른쪽 버튼을 클릭 후 **Compile**을 선택하거나, 툴바의 **Compile** 버튼을 눌러 컴파일합니다.
#    - 오류 없이 컴파일되면 애플릿 실행이 가능합니다.
#
# #### 3. **애플릿 실행하기**
# 1. **Run Applet 메뉴 사용**
#    - 컴파일된 애플릿 클래스의 팝업 메뉴에서 **Run Applet**을 선택합니다.
#    - 대화상자에서 실행 방식을 선택합니다:
#      - **애플릿 뷰어** (JDK 내장 도구, 버전 호환성 우수)
#      - **웹 브라우저** (기본 브라우저 사용)
#      - **웹페이지만 생성** (HTML 파일만 생성)
#    - **OK**를 클릭하면 애플릿이 실행됩니다.
#      - 애플릿 뷰어가 기본 선택되며, 브라우저에서 실행 시 버전 차이로 문제 발생 가능성이 있습니다.
#
# 2. **객체 벤치에서 테스트**
#    - 애플릿 객체를 생성하여 일부 메소드를 테스트할 수 있지만, 완전한 실행은 불가능합니다.
#    - 팝업 메뉴에서 생성자를 선택해 객체를 생성한 후, 메소드를 직접 호출할 수 있습니다.
#
# #### 4. **디버깅 (중단점 사용)**
#    - **일반 디버깅 제한 사항**:
#      - 애플릿 뷰어나 브라우저에서 실행 시 BlueJ의 중단점이 무시됩니다.
#    - **해결 방법**:
#      - Michael Trigoboff의 **AppletWindow** 클래스를 사용합니다.
#      - 이 클래스는 BlueJ 홈페이지에서 다운로드가 가능하며, 애플릿을 BlueJ 환경 내에서 직접 실행해 디버깅할 수 있게 합니다.
#      - 중단점을 설정하고 **Step** 버튼 등을 이용해 단계별 실행이 가능합니다.
#
# #### 5. **예제 프로젝트 활용**
#    - **appletdemo** 프로젝트(예제 디렉토리 내)를 열어 `CaseConverter` 애플릿을 실행해 볼 수 있습니다.
#    - 이 예제는 애플릿 실행 및 HTML 생성 절차를 학습하는 데 도움이 됩니다.
#
# #### 6. **기타 기능**
#    - **HTML 파일 생성**:
#      - 애플릿 실행 시 자동으로 HTML 파일이 생성되며, 브라우저에서 이 파일을 열어 테스트할 수 있습니다.
#    - **외부 패키지 추가**:
#      - 애플릿에 필요한 라이브러리는 **Tools > Use Libraries Class** 메뉴로 추가할 수 있습니다.
#
# ---
#
# ### 참고: 문서에 없는 정보
# - 애플릿의 `init` 또는 `start` 메소드 사용법, HTML 태그 작성 예시 등은 문서에 명시되지 않았습니다.
# - "문서에서 찾을 수 없습니다."로 답변해야 합니다.
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

# question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"
question = "현재 기온은 몇도인가요?"

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# notGrounded
